# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course)

# %% [markdown]
# ## Introduction
# In this notebook I will create a pipeline with the following steps:
#
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.
# 9. Deploy the pipeline/REST endpoint for future reuse/retraining of the dataset
# 10. Deploy the model.

# %% [markdown]
# ## Timestamp

# %%
from datetime import datetime
print(f'{datetime.now().strftime("%d/%m/%Y %H:%M:%S")} CET-1')
# Out:
# 18/01/2021 09:07:04 CET-1

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.19.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# Michaels_test1
# MS_Test
# northeurope
# 336509a3-005c-4650-b1e5-e1c99e57a5e1

# %% [markdown]
# ## Create an Azure ML experiment
# First we will create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.

# %%
experiment_name = 'automlstep-classification'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: automlstep-classification,
# Workspace: Michaels_test1)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

amlcompute_cluster_name = "auto-ml"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Creating
# Succeeded.................................................................................................................
# AmlCompute wait for completion finished
#
# Wait timeout has been reached
# Current provisioning state of AmlCompute is "Succeeded" and current node count is "0"

# %% [markdown]
# ## Data
#
# **Note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found, it will be recreated from the original source.

# %%
found = False
key = "UCI Bank marketing"
description_text = ""

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [40d70889][f8373055-348f-40d8-b205-a0c3f2be1416], (This step will run and generate new outputs)
# Submitted PipelineRun ed519d42-b96e-4db6-8edf-85d2476053da
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/automlstep-classification/runs/ed519d42-b96e-4db6-8edf-85d2476053da?wsid=/subscriptions/336509a3-005c-4650-b1e5-e1c99e57a5e1/resourcegroups/MS_Test/workspaces/Michaels_test1

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: ed519d42-b96e-4db6-8edf-85d2476053da
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/automlstep-classification/runs/ed519d42-b96e-4db6-8edf-85d2476053da?wsid=/subscriptions/336509a3-005c-4650-b1e5-e1c99e57a5e1/resourcegroups/MS_Test/workspaces/Michaels_test1
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: e2e6861a-bbfb-47cc-9099-598a222f74c3
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/automlstep-classification/runs/e2e6861a-bbfb-47cc-9099-598a222f74c3?wsid=/subscriptions/336509a3-005c-4650-b1e5-e1c99e57a5e1/resourcegroups/MS_Test/workspaces/Michaels_test1
# StepRun( automl_module ) Status: NotStarted
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': 'e2e6861a-bbfb-47cc-9099-598a222f74c3', 'target': 'auto-ml', 'status': 'Completed', 'startTimeUtc': '2021-01-18T09:18:07.737475Z', 'endTimeUtc': '2021-01-18T09:50:01.025255Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '8f2217c6-10e6-459b-bfa9-1798c0234511', 'StepType': 'AutoMLStep', 'azureml.moduleid': 'f8373055-348f-40d8-b205-a0c3f2be1416', 'azureml.nodeid': '40d70889', 'azureml.pipelinerunid': 'ed519d42-b96e-4db6-8edf-85d2476053da', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'auto-ml', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "336509a3-005c-4650-b1e5-e1c99e57a5e1", "resource_group": "MS_Test", "workspace_name": "Michaels_test1", "region": "northeurope", "compute_target": "auto-ml", "spark_service": null, "azure_service": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["KNN", "DecisionTree", "RandomForest", "AveragedPerceptronClassifier", "SVM", "GradientBoosting", "XGBoostClassifier", "TensorFlowLinearClassifier", "TensorFlowDNN", "LinearSVM", "ExtremeRandomTrees", "BernoulliNaiveBayes", "SGD", "MultinomialNaiveBayes", "LightGBM", "LogisticRegression"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_D2_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "_local_managed_run_id": null, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"954fb95f-5216-4849-b369-d40c69c3ddc9\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': '8f2217c6-10e6-459b-bfa9-1798c0234511', 'SetupRunId': 'e2e6861a-bbfb-47cc-9099-598a222f74c3_setup', 'SetupRunContainerId': 'dcid.e2e6861a-bbfb-47cc-9099-598a222f74c3_setup', 'ClientSdkVersion': '1.19.0', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': 'e2e6861a-bbfb-47cc-9099-598a222f74c3_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": false, "dataset_classes": 2, "dataset_features":  ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'ed519d42-b96e-4db6-8edf-85d2476053da', 'status': 'Completed', 'startTimeUtc': '2021-01-18T09:17:42.743304Z', 'endTimeUtc': '2021-01-18T09:51:58.027282Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://michaelstest16096096377.blob.core.windows.net/azureml/ExperimentRun/dcid.ed519d42-b96e-4db6-8edf-85d2476053da/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=pR7Hqi4dlDH2rHFliEH0bRQCmoXKj1ZUbqxJI78PxyY%3D&st=2021-01-18T09%3A08%3A03Z&se=2021-01-18T17%3A18%3A03Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://michaelstest16096096377.blob.core.windows.net/azureml/ExperimentRun/dcid.ed519d42-b96e-4db6-8edf-85d2476053da/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=vBhMnCJNGo8QmBzAaRj90AbQAJwxNqgrc%2B60IAweLg4%3D&st=2021-01-18T09%3A08%3A03Z&se=2021-01-18T17%3A18%3A03Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://michaelstest16096096377.blob.core.windows.net/azureml/ExperimentRun/dcid.ed519d42-b96e-4db6-8edf-85d2476053da/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=zZoyvMQ68eZC6pQ6Cv41%2Fl%2B4HExi2xsJKyGcucecp7s%3D&st=2021-01-18T09%3A08%3A03Z&se=2021-01-18T17%3A18%3A03Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/e2e6861a-bbfb-47cc-9099-598a222f74c3/metrics_data
# Downloaded azureml/e2e6861a-bbfb-47cc-9099-598a222f74c3/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_5  \
# recall_score_macro                                 [0.5942781010175104]
# AUC_weighted                                       [0.9033369639916495]
# recall_score_micro                                 [0.8977238239757208]
# average_precision_score_macro                      [0.7413308095396651]
# accuracy                                           [0.8977238239757208]
# AUC_micro                                          [0.9686175540721331]
# recall_score_weighted                              [0.8977238239757208]
# f1_score_weighted                                  [0.8734704046383025]
# f1_score_macro                                     [0.6263947343363969]
# average_precision_score_micro                      [0.9695415278906149]
# AUC_macro                                          [0.9033369639916495]
# average_precision_score_weighted                   [0.9317734012392973]
# precision_score_weighted                            [0.877014103638037]
# precision_score_micro                              [0.8977238239757208]
# norm_macro_recall                                 [0.18855620203502088]
# precision_score_macro                               [0.771526544069397]
# log_loss                                           [0.2376721425311598]
# balanced_accuracy                                  [0.5942781010175104]
# weighted_accuracy                                  [0.9730611889183236]
# f1_score_micro                                     [0.8977238239757208]
# matthews_correlation                              [0.31999379338174755]
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_9  \
# recall_score_macro                                 [0.7373505826650885]
# AUC_weighted                                       [0.7964478824555846]
# recall_score_micro                                 [0.7417298937784522]
# average_precision_score_macro                      [0.6933118429235139]
# accuracy                                           [0.7417298937784522]
# AUC_micro                                          [0.8098144749597611]
# recall_score_weighted                              [0.7417298937784522]
# f1_score_weighted                                  [0.7861323831564938]
# f1_score_macro                                     [0.6122622984097064]
# average_precision_score_micro                      [0.7743738735025619]
# AUC_macro                                          [0.7964478824555846]
# average_precision_score_weighted                   [0.8994138121844297]
# precision_score_weighted                           [0.8789208060237718]
# precision_score_micro                              [0.7417298937784522]
# norm_macro_recall                                  [0.4747011653301769]
# precision_score_macro                              [0.6103165467502021]
# log_loss                                           [0.5695872870247711]
# balanced_accuracy                                  [0.7373505826650885]
# weighted_accuracy                                  [0.7428171582695392]
# f1_score_micro                                     [0.7417298937784522]
# matthews_correlation                              [0.32362754301054747]
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_14  \
# recall_score_macro                                  [0.5275888353552025]
# AUC_weighted                                        [0.8964618678996087]
# recall_score_micro                                  [0.8907435508345979]
# average_precision_score_macro                       [0.7314846617231889]
# accuracy                                            [0.8907435508345979]
# AUC_micro                                           [0.9669262067647446]
# recall_score_weighted                               [0.8907435508345979]
# f1_score_weighted                                   [0.8485301482553879]
# f1_score_macro                                      [0.5253574824019744]
# average_precision_score_micro                       [0.9669263178092227]
# AUC_macro                                           [0.8964618678996087]
# average_precision_score_weighted                    [0.9275580088673532]
# precision_score_weighted                            [0.8638829714370829]
# precision_score_micro                               [0.8907435508345979]
# norm_macro_recall                                 [0.055177670710405025]
# precision_score_macro                               [0.7610648553900088]
# log_loss                                           [0.24701742298978088]
# balanced_accuracy                                   [0.5275888353552025]
# weighted_accuracy                                   [0.9809050435192916]
# f1_score_micro                                      [0.8907435508345979]
# matthews_correlation                               [0.16973479681414416]
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_21  \
# recall_score_macro                                  [0.7400105955946777]
# AUC_weighted                                         [0.943998021661693]
# recall_score_micro                                  [0.9125948406676783]
# average_precision_score_macro                       [0.8126929119384294]
# accuracy                                            [0.9125948406676783]
# AUC_micro                                           [0.9792565642982309]
# recall_score_weighted                               [0.9125948406676783]
# f1_score_weighted                                   [0.9086613440609772]
# f1_score_macro                                      [0.7607503025413473]
# average_precision_score_micro                       [0.9802395848606664]
# AUC_macro                                            [0.943998021661693]
# average_precision_score_weighted                    [0.9525161907226625]
# precision_score_weighted                            [0.9062798949414683]
# precision_score_micro                               [0.9125948406676783]
# norm_macro_recall                                   [0.4800211911893555]
# precision_score_macro                                 [0.78754962860383]
# log_loss                                           [0.17981385781039308]
# balanced_accuracy                                   [0.7400105955946777]
# weighted_accuracy                                   [0.9554428403944659]
# f1_score_micro                                      [0.9125948406676783]
# matthews_correlation                                [0.5254139610791995]
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_6  \
# recall_score_macro                                  [0.591580114365737]
# AUC_weighted                                       [0.8877214284788097]
# recall_score_micro                                 [0.8992412746585736]
# average_precision_score_macro                      [0.7445333239562871]
# accuracy                                           [0.8992412746585736]
# AUC_micro                                          [0.9656136925170569]
# recall_score_weighted                              [0.8992412746585736]
# f1_score_weighted                                  [0.8736703375046865]
# f1_score_macro                                     [0.6241097027623611]
# average_precision_score_micro                      [0.9667846610233417]
# AUC_macro                                          [0.8877214284788097]
# average_precision_score_weighted                   [0.9305273899617822]
# precision_score_weighted                            [0.880639596948415]
# precision_score_micro                              [0.8992412746585736]
# norm_macro_recall                                 [0.18316022873147397]
# precision_score_macro                              [0.7898676696490343]
# log_loss                                           [0.2506104472406029]
# balanced_accuracy                                   [0.591580114365737]
# weighted_accuracy                                  [0.9756252186657136]
# f1_score_micro                                     [0.8992412746585736]
# matthews_correlation                               [0.3258595669142658]
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_12  \
# recall_score_macro                                  [0.7340556676243455]
# AUC_weighted                                        [0.8617807452852382]
# recall_score_micro                                  [0.7274658573596358]
# average_precision_score_macro                       [0.7201326490514048]
# accuracy                                            [0.7274658573596358]
# AUC_micro                                           [0.8352297245331939]
# recall_score_weighted                               [0.7274658573596358]
# f1_score_weighted                                   [0.7754305685403369]
# f1_score_macro                                      [0.6022020847987368]
# average_precision_score_micro                       [0.8278612717741654]
# AUC_macro                                           [0.8617807452852382]
# average_precision_score_weighted                    [0.9219464699587266]
# precision_score_weighted                            [0.8784682308206491]
# precision_score_micro                               [0.7274658573596358]
# norm_macro_recall                                    [0.468111335248691]
# precision_score_macro                               [0.6057895098179578]
# log_loss                                            [0.5792701996692573]
# balanced_accuracy                                   [0.7340556676243455]
# weighted_accuracy                                   [0.7258297857222601]
# f1_score_micro                                      [0.7274658573596358]
# matthews_correlation                                [0.3147102435453561]
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_13  \
# recall_score_macro                                  [0.6227454260188535]
# AUC_weighted                                        [0.9308878256246675]
# recall_score_micro                                  [0.9062215477996965]
# average_precision_score_macro                       [0.7985126174047921]
# accuracy                                            [0.9062215477996965]
# AUC_micro                                           [0.9758990146932517]
# recall_score_weighted                               [0.9062215477996965]
# f1_score_weighted                                    [0.885603431576398]
# f1_score_macro                                      [0.6650154684677185]
# average_precision_score_micro                       [0.9766643355999638]
# AUC_macro                                           [0.9308878256246677]
# average_precision_score_weighted                     [0.947605275820125]
# precision_score_weighted                            [0.8929725418691179]
# precision_score_micro                               [0.9062215477996965]
# norm_macro_recall                                  [0.24549085203770704]
# precision_score_macro                                [0.822098675416211]
# log_loss                                           [0.33655623030329523]
# balanced_accuracy                                   [0.6227454260188535]
# weighted_accuracy                                   [0.9766010009385309]
# f1_score_micro                                      [0.9062215477996965]
# matthews_correlation                                [0.3976739324324451]
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_4  \
# recall_score_macro                                                [0.5]
# AUC_weighted                                       [0.8957283267296106]
# recall_score_micro                                 [0.8880121396054628]
# average_precision_score_macro                      [0.7179724772514763]
# accuracy                                           [0.8880121396054628]
# AUC_micro                                          [0.9667197966293712]
# recall_score_weighted                              [0.8880121396054628]
# f1_score_weighted                                  [0.8353395018439429]
# f1_score_macro                                     [0.4703423886834914]
# average_precision_score_micro                      [0.9678984877025256]
# AUC_macro                                          [0.8957283267296106]
# average_precision_score_weighted                   [0.9256282968565512]
# precision_score_weighted                            [0.788565560086672]
# precision_score_micro                              [0.8880121396054628]
# norm_macro_recall                                                 [0.0]
# precision_score_macro                              [0.4440060698027314]
# log_loss                                           [0.2546832229397322]
# balanced_accuracy                                                 [0.5]
# weighted_accuracy                                  [0.9843450583187134]
# f1_score_micro                                     [0.8880121396054628]
# matthews_correlation                                              [0.0]
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_2  \
# recall_score_macro                                  [0.531653876005609]
# AUC_weighted                                       [0.8984439109599571]
# recall_score_micro                                 [0.8916540212443096]
# average_precision_score_macro                      [0.7413315236910009]
# accuracy                                           [0.8916540212443096]
# AUC_micro                                          [0.9673514613809953]
# recall_score_weighted                              [0.8916540212443096]
# f1_score_weighted                                  [0.8504969631222853]
# f1_score_macro                                     [0.5325555805905151]
# average_precision_score_micro                      [0.9664613869187597]
# AUC_macro                                          [0.8984439109599571]
# average_precision_score_weighted                   [0.9292351983129676]
# precision_score_weighted                            [0.867897704653235]
# precision_score_micro                              [0.8916540212443096]
# norm_macro_recall                                 [0.06330775201121797]
# precision_score_macro                              [0.7761380346783446]
# log_loss                                           [0.2386007087302676]
# balanced_accuracy                                   [0.531653876005609]
# weighted_accuracy                                  [0.9810323194679199]
# f1_score_micro                                     [0.8916540212443096]
# matthews_correlation                              [0.18698490966001377]
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_7  ...  \
# recall_score_macro                                 [0.5023682636006127]  ...
# AUC_weighted                                       [0.8661898649061679]  ...
# recall_score_micro                                 [0.8880121396054628]  ...
# average_precision_score_macro                      [0.7244936189210119]  ...
# accuracy                                           [0.8880121396054628]  ...
# AUC_micro                                          [0.9608459039193518]  ...
# recall_score_weighted                              [0.8880121396054628]  ...
# f1_score_weighted                                  [0.8365065546222373]  ...
# f1_score_macro                                     [0.4756852373561897]  ...
# average_precision_score_micro                      [0.9622290999891723]  ...
# AUC_macro                                          [0.8661898649061679]  ...
# average_precision_score_weighted                   [0.9235598885387498]  ...
# precision_score_weighted                           [0.8449782803055558]  ...
# precision_score_micro                              [0.8880121396054628]  ...
# norm_macro_recall                                [0.004736527201225416]  ...
# precision_score_macro                               [0.694241871771498]  ...
# log_loss                                          [0.27087390389816784]  ...
# balanced_accuracy                                  [0.5023682636006127]  ...
# weighted_accuracy                                  [0.9837570825271279]  ...
# f1_score_micro                                     [0.8880121396054628]  ...
# matthews_correlation                              [0.04289596506112579]  ...
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_11  \
# recall_score_macro                                  [0.8159075626983201]
# AUC_weighted                                        [0.8918814034346768]
# recall_score_micro                                  [0.7235204855842186]
# average_precision_score_macro                       [0.7431835351424296]
# accuracy                                            [0.7235204855842186]
# AUC_micro                                           [0.8373579318459706]
# recall_score_weighted                               [0.7235204855842186]
# f1_score_weighted                                   [0.7741241915854847]
# f1_score_macro                                      [0.6241894566547341]
# average_precision_score_micro                       [0.8542157641932784]
# AUC_macro                                           [0.8918814034346769]
# average_precision_score_weighted                     [0.930926365523707]
# precision_score_weighted                            [0.9090416487343209]
# precision_score_micro                               [0.7235204855842186]
# norm_macro_recall                                   [0.6318151253966402]
# precision_score_macro                               [0.6341994620745227]
# log_loss                                            [0.4782387212157143]
# balanced_accuracy                                   [0.8159075626983201]
# weighted_accuracy                                   [0.7005832733649381]
# f1_score_micro                                      [0.7235204855842187]
# matthews_correlation                               [0.41179910140449844]
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_17  \
# recall_score_macro                                  [0.7388764779650531]
# AUC_weighted                                        [0.8352926847792059]
# recall_score_micro                                  [0.7423368740515933]
# average_precision_score_macro                        [0.714054960607406]
# accuracy                                            [0.7423368740515933]
# AUC_micro                                           [0.8405828484322362]
# recall_score_weighted                               [0.7423368740515933]
# f1_score_weighted                                   [0.7866350097530707]
# f1_score_macro                                      [0.6131735503523392]
# average_precision_score_micro                       [0.8164938912412201]
# AUC_macro                                           [0.8352926847792059]
# average_precision_score_weighted                    [0.9145858247440749]
# precision_score_weighted                            [0.8794210616465955]
# precision_score_micro                               [0.7423368740515933]
# norm_macro_recall                                  [0.47775295593010614]
# precision_score_macro                               [0.6110257571439763]
# log_loss                                             [0.561512050706126]
# balanced_accuracy                                   [0.7388764779650531]
# weighted_accuracy                                    [0.743195996797751]
# f1_score_micro                                      [0.7423368740515934]
# matthews_correlation                                [0.3257081014034278]
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_19  \
# recall_score_macro                                  [0.7386435415960448]
# AUC_weighted                                        [0.9396755006511105]
# recall_score_micro                                  [0.9101669195751139]
# average_precision_score_macro                       [0.8128212119523119]
# accuracy                                            [0.9101669195751139]
# AUC_micro                                           [0.9784093708911972]
# recall_score_weighted                               [0.9101669195751139]
# f1_score_weighted                                   [0.9066478557320837]
# f1_score_macro                                      [0.7566770849549538]
# average_precision_score_micro                       [0.9794050745834078]
# AUC_macro                                           [0.9396755006511104]
# average_precision_score_weighted                    [0.9520327752925208]
# precision_score_weighted                            [0.9042986554981781]
# precision_score_micro                               [0.9101669195751139]
# norm_macro_recall                                   [0.4772870831920897]
# precision_score_macro                               [0.7792557284588055]
# log_loss                                            [0.2102510113682131]
# balanced_accuracy                                   [0.7386435415960448]
# weighted_accuracy                                   [0.9527515346984474]
# f1_score_micro                                      [0.9101669195751139]
# matthews_correlation                                 [0.516304468508235]
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_20  \
# recall_score_macro                                  [0.7320273151466989]
# AUC_weighted                                        [0.9424346157337171]
# recall_score_micro                                  [0.9068285280728376]
# average_precision_score_macro                       [0.8157953633346354]
# accuracy                                            [0.9068285280728376]
# AUC_micro                                           [0.9790613911269432]
# recall_score_weighted                               [0.9068285280728376]
# f1_score_weighted                                    [0.903378661540016]
# f1_score_macro                                      [0.7486188593571268]
# average_precision_score_micro                       [0.9800395435298067]
# AUC_macro                                           [0.9424346157337172]
# average_precision_score_weighted                    [0.9530225439592835]
# precision_score_weighted                            [0.9009533136706618]
# precision_score_micro                               [0.9068285280728376]
# norm_macro_recall                                   [0.4640546302933979]
# precision_score_macro                                [0.769173285369229]
# log_loss                                           [0.20707569863890027]
# balanced_accuracy                                   [0.7320273151466989]
# weighted_accuracy                                   [0.9502269409495937]
# f1_score_micro                                      [0.9068285280728376]
# matthews_correlation                                [0.4998221872363749]
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_22  \
# recall_score_macro                                  [0.7381429367950549]
# AUC_weighted                                        [0.9438841004951403]
# recall_score_micro                                  [0.9113808801213961]
# average_precision_score_macro                       [0.8150378454592331]
# accuracy                                            [0.9113808801213961]
# AUC_micro                                           [0.9792746171257781]
# recall_score_weighted                               [0.9113808801213961]
# f1_score_weighted                                   [0.9075232070026762]
# f1_score_macro                                      [0.7580675984486392]
# average_precision_score_micro                        [0.980258627086168]
# AUC_macro                                           [0.9438841004951403]
# average_precision_score_weighted                    [0.9530284047649816]
# precision_score_weighted                            [0.9051091556982174]
# precision_score_micro                               [0.9113808801213961]
# norm_macro_recall                                   [0.4762858735901099]
# precision_score_macro                               [0.7836182515310355]
# log_loss                                            [0.1809974148381821]
# balanced_accuracy                                   [0.7381429367950549]
# weighted_accuracy                                   [0.9543911754422495]
# f1_score_micro                                      [0.9113808801213961]
# matthews_correlation                                [0.5197756567915791]
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_16  \
# recall_score_macro                                  [0.7237907221861009]
# AUC_weighted                                        [0.8466264515686851]
# recall_score_micro                                  [0.7071320182094082]
# average_precision_score_macro                       [0.7174726015541579]
# accuracy                                            [0.7071320182094082]
# AUC_micro                                           [0.8272705460289536]
# recall_score_weighted                               [0.7071320182094082]
# f1_score_weighted                                   [0.7598142586484068]
# f1_score_macro                                      [0.5864442601895656]
# average_precision_score_micro                       [0.8011255587644794]
# AUC_macro                                           [0.8466264515686852]
# average_precision_score_weighted                    [0.9183439243120464]
# precision_score_weighted                            [0.8760425340621575]
# precision_score_micro                               [0.7071320182094082]
# norm_macro_recall                                   [0.4475814443722017]
# precision_score_macro                               [0.5981119104872026]
# log_loss                                            [0.5253050073961635]
# balanced_accuracy                                   [0.7237907221861009]
# weighted_accuracy                                   [0.7029961126223135]
# f1_score_micro                                      [0.7071320182094082]
# matthews_correlation                                [0.2963547556762951]
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_1  \
# recall_score_macro                                 [0.7191727470931578]
# AUC_weighted                                       [0.9392346349984347]
# recall_score_micro                                 [0.9071320182094081]
# average_precision_score_macro                      [0.8065229883244922]
# accuracy                                           [0.9071320182094081]
# AUC_micro                                          [0.9781770788959222]
# recall_score_weighted                              [0.9071320182094081]
# f1_score_weighted                                  [0.9021127651963996]
# f1_score_macro                                     [0.7416848907681176]
# average_precision_score_micro                      [0.9791945367231853]
# AUC_macro                                          [0.9392346349984347]
# average_precision_score_weighted                   [0.9505970434373063]
# precision_score_weighted                           [0.8991976076061607]
# precision_score_micro                              [0.9071320182094081]
# norm_macro_recall                                 [0.43834549418631563]
# precision_score_macro                              [0.7723958081530135]
# log_loss                                           [0.1874363495858499]
# balanced_accuracy                                  [0.7191727470931578]
# weighted_accuracy                                  [0.9537972210153172]
# f1_score_micro                                     [0.9071320182094081]
# matthews_correlation                                [0.488678780261868]
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_23  \
# recall_score_macro                                  [0.7508386635472644]
# AUC_weighted                                        [0.9448491887516278]
# recall_score_micro                                  [0.9128983308042489]
# average_precision_score_macro                       [0.8085204474402641]
# accuracy                                            [0.9128983308042489]
# AUC_micro                                           [0.9793693944704005]
# recall_score_weighted                               [0.9128983308042489]
# f1_score_weighted                                   [0.9100415644605403]
# f1_score_macro                                      [0.7668111420906795]
# average_precision_score_micro                        [0.980352027134298]
# AUC_macro                                           [0.9448491887516277]
# average_precision_score_weighted                    [0.9516860732237478]
# precision_score_weighted                            [0.9080335867085474]
# precision_score_micro                               [0.9128983308042489]
# norm_macro_recall                                   [0.5016773270945287]
# precision_score_macro                               [0.7860811293290488]
# log_loss                                           [0.18115151864375498]
# balanced_accuracy                                   [0.7508386635472644]
# weighted_accuracy                                   [0.9531333625443325]
# f1_score_micro                                      [0.9128983308042489]
# matthews_correlation                                [0.5357619178216784]
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_3  \
# recall_score_macro                                  [0.769209146295154]
# AUC_weighted                                       [0.8733159580399631]
# recall_score_micro                                 [0.7814871016691958]
# average_precision_score_macro                      [0.7319634297197195]
# accuracy                                           [0.7814871016691958]
# AUC_micro                                          [0.8550474001855941]
# recall_score_weighted                              [0.7814871016691958]
# f1_score_weighted                                  [0.8164915669325802]
# f1_score_macro                                     [0.6501227608387614]
# average_precision_score_micro                      [0.8231430370513239]
# AUC_macro                                          [0.8733159580399632]
# average_precision_score_weighted                   [0.9258338703119388]
# precision_score_weighted                           [0.8884973158479131]
# precision_score_micro                              [0.7814871016691958]
# norm_macro_recall                                   [0.538418292590308]
# precision_score_macro                              [0.6341988793655895]
# log_loss                                           [0.5207365673746448]
# balanced_accuracy                                   [0.769209146295154]
# weighted_accuracy                                   [0.784535385875497]
# f1_score_micro                                     [0.7814871016691958]
# matthews_correlation                               [0.3801450551974953]
#
#                                  e2e6861a-bbfb-47cc-9099-598a222f74c3_28
# recall_score_macro                                  [0.7405232408441651]
# AUC_weighted                                         [0.946320902033354]
# recall_score_micro                                    [0.91350531107739]
# average_precision_score_macro                       [0.8190416521556734]
# accuracy                                              [0.91350531107739]
# AUC_micro                                           [0.9801526661309152]
# recall_score_weighted                                 [0.91350531107739]
# f1_score_weighted                                   [0.9094201838748192]
# f1_score_macro                                      [0.7622980675794131]
# average_precision_score_micro                       [0.9810815536936628]
# AUC_macro                                            [0.946320902033354]
# average_precision_score_weighted                    [0.9541759926685919]
# precision_score_weighted                            [0.9070481320059524]
# precision_score_micro                                 [0.91350531107739]
# norm_macro_recall                                   [0.4810464816883302]
# precision_score_macro                               [0.7907734356280218]
# log_loss                                            [0.1800402517508643]
# balanced_accuracy                                   [0.7405232408441651]
# weighted_accuracy                                   [0.9564520800304727]
# f1_score_micro                                        [0.91350531107739]
# matthews_correlation                                [0.5289149991771608]
#
# [21 rows x 26 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/e2e6861a-bbfb-47cc-9099-598a222f74c3/model_data
# Downloaded azureml/e2e6861a-bbfb-47cc-9099-598a222f74c3/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                    min_weight_fraction_leaf=0.0,
#                                                                                                                                    n_estimators=25,
#                                                                                                                                    n_jobs=1,
#                                                                                                                                    oob_score=True,
#                                                                                                                                    random_state=None,
#                                                                                                                                    verbose=0,
#                                                                                                                                    warm_start=False))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.42857142857142855,
#                                                                                          0.2857142857142857,
#                                                                                          0.07142857142857142,
#                                                                                          0.07142857142857142,
#                                                                                          0.07142857142857142,
#                                                                                          0.07142857142857142]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('0',
#                                              Pipeline(memory=None,
#                                                       steps=[('maxabsscaler',
#                                                               MaxAbsScaler(copy=True)),
#                                                              ('lightgbmclassifier',
#                                                               LightGBMClassifier(boosting_type='gbdt',
#                                                                                  class_weight=None,
#                                                                                  colsample_bytree=1.0,
#                                                                                  importance_type='split',
#                                                                                  learning_rate=0.1,
#                                                                                  max_depth=-1,
#                                                                                  min_child_samples=20,
#                                                                                  min_child_weight=0.001,
#                                                                                  min_spl...
#                                                                                    min_impurity_split=None,
#                                                                                    min_samples_leaf=0.01,
#                                                                                    min_samples_split=0.056842105263157895,
#                                                                                    min_weight_fraction_leaf=0.0,
#                                                                                    n_estimators=25,
#                                                                                    n_jobs=1,
#                                                                                    oob_score=True,
#                                                                                    random_state=None,
#                                                                                    verbose=0,
#                                                                                    warm_start=False))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.42857142857142855, 0.2857142857142857,
#                                          0.07142857142857142, 0.07142857142857142,
#                                          0.07142857142857142,
#                                          0.07142857142857142]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_ece90b56_5972_11eb_bc49_000d3ab00b1crow0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_ece90b56_5972_11eb_bc49_000d3ab00b1crow0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_ece90b56_5972_11eb_bc49_000d3ab00b1crow1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_ece90b56_5972_11eb_bc49_000d3ab00b1crow1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_ece90b56_5972_11eb_bc49_000d3ab00b1c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ece90b56_5972_11eb_bc49_000d3ab00b1clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ece90b56_5972_11eb_bc49_000d3ab00b1crow0_col0" class="data row0 col0" >28709</td>
#                         <td id="T_ece90b56_5972_11eb_bc49_000d3ab00b1crow0_col1" class="data row0 col1" >549</td>
#             </tr>
#             <tr>
#                         <th id="T_ece90b56_5972_11eb_bc49_000d3ab00b1clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ece90b56_5972_11eb_bc49_000d3ab00b1crow1_col0" class="data row1 col0" >1205</td>
#                         <td id="T_ece90b56_5972_11eb_bc49_000d3ab00b1crow1_col1" class="data row1 col1" >2487</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: c9d47e50-eaad-4f56-8c9d-9846c6ccb0c6,
# Status: Active,
# Endpoint: https://northeurope.api.azureml.ms/pipelines/v1.0/subscriptions/336509a3-005c-4650-b1e5-e1c99e57a5e1/resourceGroups/MS_Test/providers/Microsoft.MachineLearningServices/workspaces/Michaels_test1/PipelineRuns/PipelineSubmit/c9d47e50-eaad-4f56-8c9d-9846c6ccb0c6)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  bce7ba7c-2260-4cbd-8939-c7e5dbcbc81d

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
